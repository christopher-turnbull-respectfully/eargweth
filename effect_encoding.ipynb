# %%
from pandas import read_csv
file_path = "/workspaces/eargweth/kc_house_data-1 (10).csv"
df = read_csv(file_path)

# %%
# !pip install category_encoders
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from category_encoders.sum_coding import SumEncoder

my_encoder = SumEncoder()

# %%
something = my_encoder.fit_transform(X = df['roof_type'])

# %%
from pandas import concat
cdf = concat([df, something], axis=1)
display(cdf)
# Out:
#                id             date  ...  roof_type_0  roof_type_1
# 0      7129300520  20141013T000000  ...          1.0          0.0
# 1      6414100192  20141209T000000  ...          0.0          1.0
# 2      5631500400  20150225T000000  ...         -1.0         -1.0
# 3      2487200875  20141209T000000  ...          1.0          0.0
# 4      1954400510  20150218T000000  ...          1.0          0.0
# ...           ...              ...  ...          ...          ...
# 18764  1525069021  20141201T000000  ...          1.0          0.0
# 18765  5076700115  20150223T000000  ...         -1.0         -1.0
# 18766  3332000615  20141020T000000  ...          1.0          0.0
# 18767  3332000615  20150422T000000  ...          1.0          0.0
# 18768  5569620410  20140909T000000  ...         -1.0         -1.0
#
# [18769 rows x 24 columns]

# %%
unique_vals = df['roof_type'].unique()

# %%
name_dict = {}


for index, val in enumerate(unique_vals):
    name_dict[f'roof_type_{index}'] = 'roof_type_' + val

cdf = cdf.rename(columns = name_dict)

display(cdf)
# Out:
#                id             date  ...  roof_type_Asphalt  roof_type_Clay
# 0      7129300520  20141013T000000  ...                1.0             0.0
# 1      6414100192  20141209T000000  ...                0.0             1.0
# 2      5631500400  20150225T000000  ...               -1.0            -1.0
# 3      2487200875  20141209T000000  ...                1.0             0.0
# 4      1954400510  20150218T000000  ...                1.0             0.0
# ...           ...              ...  ...                ...             ...
# 18764  1525069021  20141201T000000  ...                1.0             0.0
# 18765  5076700115  20150223T000000  ...               -1.0            -1.0
# 18766  3332000615  20141020T000000  ...                1.0             0.0
# 18767  3332000615  20150422T000000  ...                1.0             0.0
# 18768  5569620410  20140909T000000  ...               -1.0            -1.0
#
# [18769 rows x 24 columns]
